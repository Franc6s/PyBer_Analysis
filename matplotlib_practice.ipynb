# %%
# %matplotlib inline

# %%
#Import dependencies

import matplotlib.pyplot as plt

# %%
#set x axis as a list for each month
x_axis = ["Jan", "Feb","Mar","April","May","June","July","Aug","Sept","Oct","Nov","Dec"]

#set y axis as a list of fare in U.S. Dollars
y_axis = [10.02,23.24,39.20,35.42,32.34,27.04,43.82,10.56,11.85,27.90,20.71,20.09]

plt.plot(x_axis, y_axis)

# %%
#Create a plot with ax.plt()

fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
plt.plot(x_axis, y_axis)
plt.show()

# %%
plt.plot(x_axis, y_axis, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="blue", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#Skill Drill

plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()

# %%
#Create a vertical bar chart
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#Create a plot 
plt.bar(x_axis,y_axis, color="green", label = 'Boston')
plt.xlabel("Date")
plt.ylabel("Fare ($)")
plt.title(" PyBer Fare by Month")
plt.legend()

# %%
#Create an horizontal bar chart
plt.barh(x_axis,y_axis, color="orange", label = 'Boston')
# Out:
# <BarContainer object of 12 artists>

# %%
#to switch axis around
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
#to invert axis and put the date from Jan to Dec
#use the gca() method
plt.barh(x_axis,y_axis,color="turquoise", label="Boston")
plt.gca().invert_yaxis()
plt.legend()

# %%
#Create a vertical Bar chart with the object oriented approach
#Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color = "black",label = "New-York")
ax.legend()

# %%
fix, ax = plt.subplots()
ax.barh(x_axis,y_axis, color="yellow")
# Out:
# <BarContainer object of 12 artists>

# %%
fix, ax = plt.subplots()
ax.barh(x_axis,y_axis,color="cyan", label="Chicago")
plt.gca().invert_yaxis()
ax.set_xlabel("Fares ($)")
ax.set_ylabel("Month")
ax.set_title("PyBer Fare by Month")
ax.legend()

# %%
#Create a scatterplot
#to create a scatter plot, we need to create a lowercase"o"
#option 1 : plt.plot(x_axis,y_axis,'o')
#option 2: plt.scatter()
plt.plot(x_axis,y_axis,'o')

# %%
plt.scatter(y_axis,x_axis, color="red", label ="Chicago")
plt.xlabel("Fares($)")
plt.ylabel("Month")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()
plt.xlim(0,50)
plt.legend()

# %%
#Create a bubble chart using Matlab method

# %%
plt.scatter(x_axis, y_axis,s=y_axis)
#to change the size of the marker use s

# %%
#to set the marker bigger
y_axis_larger =[]
for data in y_axis:
    y_axis_larger.append(data*5)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
#Create a scatter plot using the object oriented interface
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=y_axis)

# %%
#skill drill 
fig, ax = plt.subplots(figsize =(7,5))
ax.scatter(y_axis, x_axis, s=y_axis_larger,c="cyan",label="Boston",edgecolor="black")
plt.gca().invert_yaxis()
ax.set_title("PyBer Fare by Month")
ax.set_xlabel(" Fares ($)")
ax.set_ylabel("Date")
ax.legend()
ax.set_xlim(0,50)
# Out:
# (0.0, 50.0)

# %%
#Create a pie chart
plt.subplots(figsize=(10, 10))

plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')

explode_values = (0,0,0,0,0,0,0.3,0,0,0,0,0)



plt.show()

# %%
#Assign new colors, one for each month.
plt.subplots(figsize=(10, 10))

explode_values = (0,0,0,0,0,0,0.3,0,0,0,0,0)

colors =["slateblue","magenta","lightblue","green","yellowgreen","greenyellow","yellow","orange","gold","indianred","tomato","mistyrose"]

plt.pie(y_axis,explode=explode_values, labels=x_axis,colors=colors,autopct='%.1f%%')
plt.show()

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import statistics

# %%
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#Get the standard deviation
stdev = statistics.stdev(y_axis)
stdev
# Out:
# 11.208367917035753

# %%
#add error bar to a line chart

plt.errorbar(x_axis,y_axis,yerr=stdev)
# Out:
# <ErrorbarContainer object of 3 artists>
